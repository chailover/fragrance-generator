# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns

# %%
fragrance_data = pd.read_csv('../data/fra_cleaned.csv', sep = ';', on_bad_lines='skip', encoding_errors='ignore')
df = pd.DataFrame(fragrance_data)
df.head()
# Out:
#                                                  url  \
# 0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1  https://www.fragrantica.com/perfume/jean-paul-...
# 2  https://www.fragrantica.com/perfume/jean-paul-...
# 3  https://www.fragrantica.com/perfume/bruno-bana...
# 4  https://www.fragrantica.com/perfume/jean-paul-...
#
#                           Perfume               Brand  Country  Gender  \
# 0  accento-overdose-pride-edition             xerjoff    Italy  unisex
# 1            classique-pride-2024  jean-paul-gaultier   France   women
# 2            classique-pride-2023  jean-paul-gaultier   France  unisex
# 3               pride-edition-man        bruno-banani  Germany     men
# 4         le-male-pride-collector  jean-paul-gaultier   France     men
#
#   Rating Value  Rating Count    Year  \
# 0         1,42           201  2022.0
# 1         1,86            70  2024.0
# 2         1,91           285  2023.0
# 3         1,92            59  2019.0
# 4         1,93           632  2020.0
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                                 yuzu, citruses
# 2                             blood orange, yuzu
# 3                 guarana, grapefruit, red apple
# 4  mint, lavender, cardamom, artemisia, bergamot
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             orange blossom, neroli
# 2                             neroli, orange blossom
# 3                            walnut, lavender, guava
# 4                  caraway, cinnamon, orange blossom
#
#                                             Base             Perfumer1  \
# 0                               eucalyptus, pine               unknown
# 1                             musk, blonde woods               unknown
# 2                              musk, white woods  natalie gracia-cetto
# 3                        vetiver, benzoin, amber               unknown
# 4  vanilla, sandalwood, amber, cedar, tonka bean     francis kurkdjian
#
#        Perfumer2 mainaccord1   mainaccord2  mainaccord3  mainaccord4  \
# 0            NaN        rose         woody       fruity     aromatic
# 1            NaN      citrus  white floral        sweet        fresh
# 2  quentin bisch      citrus  white floral        sweet  fresh spicy
# 3            NaN      fruity         nutty        woody     tropical
# 4            NaN    aromatic    warm spicy  fresh spicy     cinnamon
#
#   mainaccord5
# 0      floral
# 1       musky
# 2       musky
# 3         NaN
# 4     vanilla

# %%
df['Notes'] = df[df.columns[8:10]].apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1  https://www.fragrantica.com/perfume/jean-paul-...
# 2  https://www.fragrantica.com/perfume/jean-paul-...
# 3  https://www.fragrantica.com/perfume/bruno-bana...
# 4  https://www.fragrantica.com/perfume/jean-paul-...
#
#                           Perfume               Brand  Country  Gender  \
# 0  accento-overdose-pride-edition             xerjoff    Italy  unisex
# 1            classique-pride-2024  jean-paul-gaultier   France   women
# 2            classique-pride-2023  jean-paul-gaultier   France  unisex
# 3               pride-edition-man        bruno-banani  Germany     men
# 4         le-male-pride-collector  jean-paul-gaultier   France     men
#
#   Rating Value  Rating Count    Year  \
# 0         1,42           201  2022.0
# 1         1,86            70  2024.0
# 2         1,91           285  2023.0
# 3         1,92            59  2019.0
# 4         1,93           632  2020.0
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                                 yuzu, citruses
# 2                             blood orange, yuzu
# 3                 guarana, grapefruit, red apple
# 4  mint, lavender, cardamom, artemisia, bergamot
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             orange blossom, neroli
# 2                             neroli, orange blossom
# 3                            walnut, lavender, guava
# 4                  caraway, cinnamon, orange blossom
#
#                                             Base             Perfumer1  \
# 0                               eucalyptus, pine               unknown
# 1                             musk, blonde woods               unknown
# 2                              musk, white woods  natalie gracia-cetto
# 3                        vetiver, benzoin, amber               unknown
# 4  vanilla, sandalwood, amber, cedar, tonka bean     francis kurkdjian
#
#        Perfumer2 mainaccord1   mainaccord2  mainaccord3  mainaccord4  \
# 0            NaN        rose         woody       fruity     aromatic
# 1            NaN      citrus  white floral        sweet        fresh
# 2  quentin bisch      citrus  white floral        sweet  fresh spicy
# 3            NaN      fruity         nutty        woody     tropical
# 4            NaN    aromatic    warm spicy  fresh spicy     cinnamon
#
#   mainaccord5                                              Notes
# 0      floral  fruity notes, aldehydes, green notes,bulgarian...
# 1       musky              yuzu, citruses,orange blossom, neroli
# 2       musky          blood orange, yuzu,neroli, orange blossom
# 3         NaN  guarana, grapefruit, red apple,walnut, lavende...
# 4     vanilla  mint, lavender, cardamom, artemisia, bergamot,...

# %%
df["Notes"] = df["Notes"].str.split(",")
Perfume_Notes = df["Perfume"], df["Notes"]
Perfume_Notes = pd.DataFrame(Perfume_Notes).T
Perfume_Notes.columns = ["Name", "Notes"]

# %%
Perfume_Notes.head()
# Out:
#                              Name  \
# 0  accento-overdose-pride-edition
# 1            classique-pride-2024
# 2            classique-pride-2023
# 3               pride-edition-man
# 4         le-male-pride-collector
#
#                                                Notes
# 0  [fruity notes,  aldehydes,  green notes, bulga...
# 1         [yuzu,  citruses, orange blossom,  neroli]
# 2     [blood orange,  yuzu, neroli,  orange blossom]
# 3  [guarana,  grapefruit,  red apple, walnut,  la...
# 4  [mint,  lavender,  cardamom,  artemisia,  berg...

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(Perfume_Notes["Notes"].apply(lambda x: ' '.join(x)))
vectorizer.get_feature_names_out()
# Out:
# array(['absinthe', 'absolute', 'acai', ..., 'zefir', 'zest', 'zinnia'],
#       dtype=object)

# %%
count_vect_df = pd.DataFrame(X.todense(), columns=vectorizer.get_feature_names_out())
pd.concat([Perfume_Notes["Name"], count_vect_df], axis=1).head()
cosine_sim = cosine_similarity(X, X)
cosine_sim_df = pd.DataFrame(cosine_sim, index=Perfume_Notes["Name"], columns=Perfume_Notes["Name"])
cosine_sim_df.head()
# Out:
# Name                            accento-overdose-pride-edition  \
# Name
# accento-overdose-pride-edition                             1.0
# classique-pride-2024                                       0.0
# classique-pride-2023                                       0.0
# pride-edition-man                                          0.0
# le-male-pride-collector                                    0.0
#
# Name                            classique-pride-2024  classique-pride-2023  \
# Name
# accento-overdose-pride-edition              0.000000              0.000000
# classique-pride-2024                        1.000000              0.790569
# classique-pride-2023                        0.790569              1.000000
# pride-edition-man                           0.000000              0.000000
# le-male-pride-collector                     0.298142              0.353553
#
# Name                            pride-edition-man  le-male-pride-collector  \
# Name
# accento-overdose-pride-edition           0.000000                 0.000000
# classique-pride-2024                     0.000000                 0.298142
# classique-pride-2023                     0.000000                 0.353553
# pride-edition-man                        1.000000                 0.125988
# le-male-pride-collector                  0.125988                 1.000000
#
# Name                            le-male-pride-2023  le-male-pride-2024  \
# Name
# accento-overdose-pride-edition            0.000000            0.000000
# classique-pride-2024                      0.790569            1.000000
# classique-pride-2023                      1.000000            0.790569
# pride-edition-man                         0.000000            0.000000
# le-male-pride-collector                   0.353553            0.298142
#
# Name                            polo-red-pride-edition  ralph-pride-edition  \
# Name
# accento-overdose-pride-edition                0.000000             0.086066
# classique-pride-2024                          0.000000             0.149071
# classique-pride-2023                          0.000000             0.117851
# pride-edition-man                             0.267261             0.125988
# le-male-pride-collector                       0.117851             0.111111
#
# Name                              waffle  ...    lavish  clipping  \
# Name                                      ...
# accento-overdose-pride-edition  0.000000  ...  0.115470  0.000000
# classique-pride-2024            0.169031  ...  0.200000  0.000000
# classique-pride-2023            0.133631  ...  0.316228  0.000000
# pride-edition-man               0.000000  ...  0.000000  0.000000
# le-male-pride-collector         0.125988  ...  0.298142  0.136083
#
# Name                            xchange-wonderman  citizen-jack-parfum  \
# Name
# accento-overdose-pride-edition           0.000000             0.069007
# classique-pride-2024                     0.000000             0.000000
# classique-pride-2023                     0.000000             0.000000
# pride-edition-man                        0.133631             0.000000
# le-male-pride-collector                  0.353553             0.089087
#
# Name                            art-collection-la-nuit-de-l-homme  floratta  \
# Name
# accento-overdose-pride-edition                           0.000000   0.63901
# classique-pride-2024                                     0.000000   0.00000
# classique-pride-2023                                     0.000000   0.00000
# pride-edition-man                                        0.188982   0.00000
# le-male-pride-collector                                  0.500000   0.00000
#
# Name                            cheval-d-arabie     khaox  aoud-no-1  \
# Name
# accento-overdose-pride-edition         0.167542  0.326599   0.097590
# classique-pride-2024                   0.000000  0.000000   0.338062
# classique-pride-2023                   0.000000  0.000000   0.400892
# pride-edition-man                      0.000000  0.000000   0.142857
# le-male-pride-collector                0.000000  0.210819   0.251976
#
# Name                            narmar-extrait-de-parfum
# Name
# accento-overdose-pride-edition                  0.223607
# classique-pride-2024                            0.000000
# classique-pride-2023                            0.000000
# pride-edition-man                               0.109109
# le-male-pride-collector                         0.384900
#
# [5 rows x 24063 columns]

# %%
def get_recommendations(name="althair", cosine_sim=cosine_sim_df):
    '''
    This function takes a perfume name and returns the top 10 most similar perfumes based on cosine similarity.
    It uses the cosine similarity matrix to find the most similar perfumes and returns their names.
    Using the Levenshtein distance, it finds similar names if the exact name is not found in the dataset.
    If the name is not found in the dataset, it returns an error message.
    Parameters:
        name (str): The name of the perfume to find recommendations for.
        cosine_sim (DataFrame): The cosine similarity matrix.
    Returns:
        DataFrame: A DataFrame containing the top 10 most similar perfumes.

    The code commented out below is another way to clean up the name input, but it seems to create a loop, 
    and it is not necessary as the get_close_matches function already handles similar names.
    '''
    # Clean up the name input
    # replacements = {" ": "", ".": "", "'": "z", "-": "", "_": "", ",": "", ";": "", ":": "", "(": "", ")": "", "[": "", "]": ""}
    # translate_table = str.maketrans(replacements)
    # name = name.translate(translate_table)
    if name not in cosine_sim.index:
        # Find similar names using the similarity it has to other perfume names through Levenshtein distance
        from difflib import get_close_matches
        similar_names = get_close_matches(name, cosine_sim.index, n=5, cutoff=0.6)
        print(f"Similar names found: {similar_names}")
        if not similar_names == []:
            name = similar_names[0]  # Use the first similar name found
            # Provide a recommendation message
            return get_recommendations(name, cosine_sim)
        else:
            # If no similar names are found, return an error message
            return f"Error: '{name}' not found in the dataset."
    # Get the pairwise similarity scores of all perfumes with that perfume
    sim_scores = list(enumerate(cosine_sim[name]))
    # Sort the perfumes based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the scores of the 10 most similar perfumes
    sim_scores = sim_scores[1:11]
    # Get the perfume indices
    perfume_indices = [i[0] for i in sim_scores]
    return Perfume_Notes["Name"].iloc[perfume_indices]

# %%
# Example usage
perfume_input = input("Enter the name of the perfume: ")
# perfume_input = "althair"
# perfume_input = "al haramain"
# perfume_input = "dior"
# perfume_input = "red tobacco"
recommendations = get_recommendations(perfume_input)
print(f"Recommendations for '{perfume_input}': \n{recommendations}")
# Out:
# Similar names found: ['althair', 'lothair', 'altamir', 'salt-air', 'althea']
# Recommendations for 'althaair':
# 24044             liquid-brun
# 12754           signature-man
# 19798         paris-sao-paulo
# 2231              oud-couture
# 3281          calypso-vanille
# 13093                 kachgar
# 13483    fuel-for-life-spirit
# 23732                il-homme
# 14070              yunnan-tea
# 18675               boundless
# Name: Name, dtype: object
